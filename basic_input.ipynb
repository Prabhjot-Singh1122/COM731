# %% [markdown]
# User_input

# %%
#Ask user to enter their name
print("what is your name human? ")
name= input()
print(f"It is nice to meet you human {name}")
# Out:
# what is your name human?
# It is nice to meet you human Moonlight

# %%
#Read a user name
name = input("what is your name human?")

# %% [markdown]
# Data type

# %%
name= input()
print(f"what is your name human? {name}")
age = int ( input())
print(f"How old are you (in years)? {age}")
height = float(input())
print(f"how tall are you (in meters)? {height}")
weight = int(input())
print(f"how much do you weigh (in kilograms)?{weight}")
Body_mass = float(input())
print(f"{name},you are {age} years old and your bmi is {Body_mass}.")
# Out:
# what is your name human? jarutas
# How old are you (in years)? 36
# how tall are you (in meters)? 1.8
# how much do you weigh (in kilograms)?52
# jarutas,you are 36 years old and your bmi is 16.05.
