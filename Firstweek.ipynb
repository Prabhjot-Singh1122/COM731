# %%
print("Hello ,WORLD!")
# Out:
# Hello ,WORLD!

# %%
a= 3
b= 4
c = a+b
print(c)
# Out:
# -1

# %% [markdown]
# #kite

# %%
#kite 
"""Hello , 
Kite"""
'''Bye Kite'''
print('Hello And Bye have a Kite')
